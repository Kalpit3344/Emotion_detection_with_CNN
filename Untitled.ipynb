# %%
import cv2
import numpy as np
import tensorflow as tf
from keras.models import model_from_json


emotion_dict = {0: "Angry", 1: "Disgusted", 2: "Fearful", 3: "Happy", 4: "Neutral", 5: "Sad", 6: "Surprised"}

# load json and create model
json_file = open('model/emotion_model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()

from tensorflow.keras.models import load_model

emotion_model = load_model("model/emotion_model.h5")
print("Model loaded successfully")
# load weights into new model

print("Loaded model from disk")
#ab no erros i want to run this 
# start the webcam feed
# cap = cv2.VideoCapture(0)
# 
# pass here your video path
# you may download one from here : https://www.pexels.com/video/three-girls-laughing-5273028/
cap = cv2.VideoCapture("C:\\JustDoIt\\ML\\Sample_videos\\emotion_sample6.mp4")

while True:
    # Find haar cascade to draw bounding box around face
    ret, frame = cap.read()
    frame = cv2.resize(frame, (1280, 720))
    if not ret:
        break
    face_detector = cv2.CascadeClassifier('haarcascades/haarcascade_frontalface_default.xml')
    gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # detect faces available on camera
    num_faces = face_detector.detectMultiScale(gray_frame, scaleFactor=1.3, minNeighbors=5)

    # take each face available on the camera and Preprocess it
    for (x, y, w, h) in num_faces:
        cv2.rectangle(frame, (x, y-50), (x+w, y+h+10), (0, 255, 0), 4)
        roi_gray_frame = gray_frame[y:y + h, x:x + w]
        cropped_img = np.expand_dims(np.expand_dims(cv2.resize(roi_gray_frame, (48, 48)), -1), 0)

        # predict the emotions
        emotion_prediction = emotion_model.predict(cropped_img)
        maxindex = int(np.argmax(emotion_prediction))
        cv2.putText(frame, emotion_dict[maxindex], (x+5, y-20), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 2, cv2.LINE_AA)

    cv2.imshow('Emotion Detection', frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 16
#      12 json_file.close()
#      14 from tensorflow.keras.models import load_model
# ---> 16 emotion_model = load_model("model/emotion_model.h5")
#      17 print("Model loaded successfully")
#      18 # load weights into new model
#
# File c:\Users\Kalpit Makwana\Desktop\Emotion_detection_with_CNN-main - Copy\.venv\Lib\site-packages\keras\src\saving\saving_api.py:195, in load_model(filepath, custom_objects, compile, safe_mode)
#     188     return saving_lib.load_model(
#     189         filepath,
#     190         custom_objects=custom_objects,
#     191         compile=compile,
#     192         safe_mode=safe_mode,
#     193     )
#     194 if str(filepath).endswith((".h5", ".hdf5")):
# --> 195     return legacy_h5_format.load_model_from_hdf5(
#     196         filepath,
#     197         custom_objects=custom_objects,
#     198         compile=compile,
#     199         safe_mode=safe_mode,
#     200     )
#     202 # Check for Orbax checkpoint directory using utility function
#     203 if is_orbax_checkpoint(filepath):
#
# File c:\Users\Kalpit Makwana\Desktop\Emotion_detection_with_CNN-main - Copy\.venv\Lib\site-packages\keras\src\legacy\saving\legacy_h5_format.py:127, in load_model_from_hdf5(filepath, custom_objects, compile, safe_mode)
#     125 model_config = f.attrs.get("model_config")
#     126 if model_config is None:
# --> 127     raise ValueError(
#     128         f"No model config found in the file at {filepath}."
#     129     )
#     130 if hasattr(model_config, "decode"):
#     131     model_config = model_config.decode("utf-8")
#
# ValueError: No model config found in the file at model/emotion_model.h5.
